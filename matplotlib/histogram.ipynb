# %%
import matplotlib.pyplot as plt

values = [3.4,5.3,5.6,6.2,6.9,7.1]

plt.hist(values, bins=3)

plt.xlabel('Values')

plt.title('Values in Bins')

plt.xticks([0,2,4,6,8,10], ['0', '2B', '4B', '6B', '8B', '10B'])

plt.grid()

plt.show()
